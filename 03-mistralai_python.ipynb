# %%
import os 
api_key = os.getenv("MISTRALAI_API_KEY")

# %%
from mistralai import Mistral
client = Mistral(api_key=api_key)

# %%
from mistralai import Mistral
import os

# Opção A: Definindo diretamente (para teste rápido)
api_key = "J8fGWgKVBc9WW1hsoahZC07SQRIwl5Ap"

# Opção B: Usando variável de ambiente (Padrão Stark de Segurança)
# api_key = os.environ.get("MISTRAL_API_KEY")

client = Mistral(api_key=api_key)

model = "codestral-latest"
chat_response = client.chat.complete(
    model=model,
    messages=[
        {"role": "user", "content": "Qual o melhor jogador do São Paulo Futebol Clube"}
    ]
)

print(chat_response.choices[0].message.content)
# Out:
# O melhor jogador do **São Paulo Futebol Clube** (SPFC) é uma questão subjetiva, pois depende de critérios como desempenho, títulos, épocas e impacto histórico. No entanto, alguns nomes se destacam como os maiores da história do clube:
#
# ### **Maiores Jogadores do São Paulo**
# 1. **Sócrates** (1971–1977) – Considerado um dos maiores jogadores da história do futebol brasileiro, Sócrates foi um dos principais responsáveis pelo **título de 1971** e pela conquista da **Taça Libertadores da América** em 1993.
# 2. **Raí** (1994–2000) – Um dos maiores ídolos da história do São Paulo, Raí foi fundamental para o **título de 1998** (o primeiro do São Paulo no século XXI) e para a conquista da **Libertadores de 1994**.
# 3. **Cafu** (1994–2004) – Zagueiro lendário, Cafu foi um dos pilares da equipe que conquistou a **Libertadores de 1994** e o **Mundial de Clubes de 1995**.
# ...

# %%
import base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

image_path = 'image/image.jpg'
base64_image = encode_image(image_path)

model = "codestral-latest"
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "text": "Descreva para mim essa imagem"
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{base64_image}"
                }
            }
        ]
    }
]

chat_response = client.chat.complete(
    model=model,
    messages=messages
)

print(chat_response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# SDKError                                  Traceback (most recent call last)
# Cell In[15], line 28
#       9 model = "codestral-latest"
#      10 messages = [
#      11     {
#      12         "role": "user",
#    (...)     25     }
#      26 ]
# ---> 28 chat_response = client.chat.complete(
#      29     model=model,
#      30     messages=messages
#      31 )
#      33 print(chat_response.choices[0].message.content)
#
# File c:\Users\Rafael\Desktop\Ia\LLM\.venv\Lib\site-packages\mistralai\chat.py:273, in Chat.complete(self, model, messages, temperature, top_p, max_tokens, stream, stop, random_seed, metadata, response_format, tools, tool_choice, presence_penalty, frequency_penalty, n, prediction, parallel_tool_calls, prompt_mode, safe_prompt, retries, server_url, timeout_ms, http_headers)
#     271 if utils.match_response(http_res, "4XX", "*"):
#     272     http_res_text = utils.stream_to_text(http_res)
# ...
